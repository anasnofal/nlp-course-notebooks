# %%
import os
import json

from dataclasses import dataclass
from collections import Counter

import gensim
import nltk
import torch
import torchmetrics

import numpy as np
import pandas as pd
import seaborn as sns

from torch import nn
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %% [markdown]
# # Setup

# %% [markdown]
# - **Word level vocab can ge generated from the tokenization notebook**

# %%
data_dir = os.path.join(os.curdir, "data")
vocab_path = os.path.join(data_dir, "word-level-vocab.json")
ara2vec_path = os.path.join(data_dir, "full_grams_cbow_100_twitter", "full_grams_cbow_100_twitter.mdl")

with open(vocab_path, "rt") as f:
    vocab = json.load(f)
    
dataset = pd.read_csv(filepath_or_buffer=dataset_path, sep="\t")
# Out:
# Downloading AraVec embeddings...
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# File ~/PythonProjects/PyTorch-learning/pytorch/lib/python3.12/site-packages/urllib3/response.py:779, in HTTPResponse._error_catcher(self)
#     778 try:
# --> 779     yield
#     781 except SocketTimeout as e:
#     782     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     783     # there is yet no clean way to get at it from this context.
#
# File ~/PythonProjects/PyTorch-learning/pytorch/lib/python3.12/site-packages/urllib3/response.py:925, in HTTPResponse._raw_read(self, amt, read1)
#     915     if (
#     916         self.enforce_content_length
#     917         and self.length_remaining is not None
#    (...)    923         # raised during streaming, so all calls with incorrect
#     924         # Content-Length are caught.
# --> 925         raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#     926 elif read1 and (
#     927     (amt != 0 and not data) or self.length_remaining == len(data)
#     928 ):
#    (...)    931     # `http.client.HTTPResponse`, so we close it here.
#     932     # See https://github.com/python/cpython/issues/113199
#
# IncompleteRead: IncompleteRead(1920144240 bytes read, 913542172 more expected)
#
# The above exception was the direct cause of the following exception:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/PythonProjects/PyTorch-learning/pytorch/lib/python3.12/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     819 try:
# --> 820     yield from self.raw.stream(chunk_size, decode_content=True)
#     821 except ProtocolError as e:
#
# File ~/PythonProjects/PyTorch-learning/pytorch/lib/python3.12/site-packages/urllib3/response.py:1091, in HTTPResponse.stream(self, amt, decode_content)
#    1090 while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1091     data = self.read(amt=amt, decode_content=decode_content)
#    1093     if data:
#
# File ~/PythonProjects/PyTorch-learning/pytorch/lib/python3.12/site-packages/urllib3/response.py:1008, in HTTPResponse.read(self, amt, decode_content, cache_content)
#    1004 while len(self._decoded_buffer) < amt and data:
#    1005     # TODO make sure to initially read enough data to get past the headers
#    1006     # For example, the GZ file header takes 10 bytes, we don't want to read
#    1007     # it one byte at a time
# -> 1008     data = self._raw_read(amt)
#    1009     decoded_data = self._decode(data, decode_content, flush_decoder)
#
# File ~/PythonProjects/PyTorch-learning/pytorch/lib/python3.12/site-packages/urllib3/response.py:903, in HTTPResponse._raw_read(self, amt, read1)
#     901 fp_closed = getattr(self._fp, "closed", False)
# --> 903 with self._error_catcher():
#     904     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#
# File /opt/homebrew/Cellar/python@3.12/3.12.10/Frameworks/Python.framework/Versions/3.12/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/PythonProjects/PyTorch-learning/pytorch/lib/python3.12/site-packages/urllib3/response.py:803, in HTTPResponse._error_catcher(self)
#     802         arg = f"Connection broken: {e!r}"
# --> 803     raise ProtocolError(arg, e) from e
#     805 except (HTTPException, OSError) as e:
#
# ProtocolError: ('Connection broken: IncompleteRead(1920144240 bytes read, 913542172 more expected)', IncompleteRead(1920144240 bytes read, 913542172 more expected))
#
# During handling of the above exception, another exception occurred:
#
# ChunkedEncodingError                      Traceback (most recent call last)
# Cell In[27], line 22
#      19 if not os.path.exists(ara2vec_path):
#      20     # Download the zip file
#      21     print("Downloading AraVec embeddings...")
# ---> 22     response = requests.get(ara2vec_link)
#      23     zip_path = "full_grams_cbow_100_twitter.zip"
#      25     with open(zip_path, "wb") as f:
#
# File ~/PythonProjects/PyTorch-learning/pytorch/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/PythonProjects/PyTorch-learning/pytorch/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/PythonProjects/PyTorch-learning/pytorch/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/PythonProjects/PyTorch-learning/pytorch/lib/python3.12/site-packages/requests/sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File ~/PythonProjects/PyTorch-learning/pytorch/lib/python3.12/site-packages/requests/models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File ~/PythonProjects/PyTorch-learning/pytorch/lib/python3.12/site-packages/requests/models.py:822, in Response.iter_content.<locals>.generate()
#     820     yield from self.raw.stream(chunk_size, decode_content=True)
#     821 except ProtocolError as e:
# --> 822     raise ChunkedEncodingError(e)
#     823 except DecodeError as e:
#     824     raise ContentDecodingError(e)
#
# ChunkedEncodingError: ('Connection broken: IncompleteRead(1920144240 bytes read, 913542172 more expected)', IncompleteRead(1920144240 bytes read, 913542172 more expected))

# %%
tweets = dataset["clean_text"].tolist()

# %%
OOV_TOKEN = "[OOV]"
PAD_TOKEN = "[PAD]"

OOV_INDEX = vocab.get(OOV_TOKEN)

print(f"Vocab Size = {len(vocab)}")
# Out:
# Vocab Size = 10998

# %%
tokenized_tweets = [[vocab.get(token) for token in tweet.split(" ") if token in vocab] for tweet in tweets]

# %%
device = torch.device('mps' if torch.backends.mps.is_available() else 'cpu')
device
# Out:
# device(type='mps')

# %% [markdown]
# # Dataset

# %% [markdown]
# ## filter dataset for empty and long sequences

# %%
# Tweets that are empty (all tokens appear less than the minimum frequency)
len([len(tweet) for tweet in tokenized_tweets if len(tweet) == 0])
# Out:
# 0

# %%
# Max Tweet length
max([len(tweet) for tweet in tokenized_tweets])
# Out:
# 72

# %%
# 99th percentile of tweets' lengths
np.percentile([len(tweet) for tweet in  tokenized_tweets], q=99)
# Out:
# 23.0

# %%
# Filtered Tweets indices by length
MIN_LENGTH = 0
MAX_LENGTH = np.percentile([len(tweet) for tweet in  tokenized_tweets], q=99)
filtered_indices = [index for index, tweet in enumerate(tokenized_tweets) if len(tweet) < MAX_LENGTH and len(tweet) > MIN_LENGTH]

# %%
X = nn.utils.rnn.pad_sequence([torch.tensor(tweet) for tweet in tokenized_tweets],
                              batch_first=True,
                              padding_value=vocab.get(PAD_TOKEN))

# %%
y = torch.tensor(dataset["Sentiment"].replace({"negative": 0, "neutral": 1, "positive": 2}).to_numpy())
# Out:
# /var/folders/tg/jhy0d12925ldvjghgc440mjh0000gn/T/ipykernel_87871/942548510.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y = torch.tensor(dataset["Sentiment"].replace({"negative": 0, "neutral": 1, "positive": 2}).to_numpy())

# %%
X, y = X[filtered_indices], y[filtered_indices]

# %%
BATCH_SIZE = 16

# %% [markdown]
# ## split training and testing set

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.15)

# %%
fig, (ax1, ax2) = plt.subplots(figsize=(12, 10), ncols=2)

train_dist = np.unique(y_train, return_counts=True)
test_dist = np.unique(y_test, return_counts=True)
labels = ["negative", "neutral", "positive"]

ax1.pie(x=train_dist[1], labels=labels)
ax2.pie(x=test_dist[1], labels=labels)

ax1.set_title("Training set label distribution")
ax2.set_title("Testing set label distribution")

plt.show()

# %% [markdown]
# ## prepare PyTorch datasets and dataloaders

# %%
train_dataset = torch.utils.data.TensorDataset(X_train, y_train)
test_dataset = torch.utils.data.TensorDataset(X_test, y_test)

train_dataloader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_dataloader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=True)

# %% [markdown]
# # Model

# %%
class SentimentAnalyzer(nn.Module):
    def __init__(
        self, 
        vocab_size: int,
        latent_dim: int,
        embedding_dim:int,
        dropout: float = 0.3,
        padding_idx: int = 0
    ):
        super().__init__()
        self.vocab_size = vocab_size
        self.embedding_dim = embedding_dim
        self.padding_idx = padding_idx
        self.latent_dim = latent_dim
        
        self.embedding = nn.Embedding(num_embeddings=self.vocab_size, 
                                      embedding_dim=self.embedding_dim, 
                                      padding_idx=self.padding_idx, 
                                      max_norm=1.0)
        
        self.rnn = nn.LSTM(
            input_size=self.embedding_dim,
            hidden_size=self.latent_dim,
            batch_first=True,
            num_layers=1,
            bidirectional=True
        )
        
        
        self.fc1 = nn.Linear(in_features=self.latent_dim * 2, out_features=3)
        self.dropout = nn.Dropout(p=dropout) 

        
    
    def forward(self, x):
        # x = (batch_size, sequence_length) 
        
        embeddings = self.embedding(x)       
        embeddings = self.dropout(embeddings)
        # embeddings = (batch_size, sequence_length, embedding_dim)
        
        hidden_states, (last_hidden_state, last_cell_state) = self.rnn(embeddings)
        
        output = torch.concat([last_hidden_state[-1,:,:], last_hidden_state[-2,:,:]], dim=-1) 
        # output = (batch_size, latent_dim * 2)
        output = self.dropout(output)
        
        output = self.fc1(output)      
        
        return output

# %%
EMBEDDING_DIM = 16
LATENT_DIM = 8
DROPOUT = 0.25

# %%
model = SentimentAnalyzer(
    vocab_size=len(vocab),
    latent_dim=LATENT_DIM,
    embedding_dim=EMBEDDING_DIM,
    dropout=DROPOUT
).to(device)

# %% [markdown]
# # Training

# %%
EPOCHS = 30
LR = 5e-4

optim = torch.optim.Adam(params=model.parameters(), lr=LR)
criterion = nn.CrossEntropyLoss()

train_metric = torchmetrics.F1Score(task="multiclass",num_classes=3).to(device)
val_metric = torchmetrics.F1Score(task="multiclass",num_classes=3).to(device)

# %%
# A dataclass object defined to store the loss and metric results of each epoch
# REFERENCE: https://realpython.com/python-data-classes/
@dataclass
class Epoch:
    epoch: int
    training_loss: float
    validation_loss: float
    training_acc: float
    validation_acc: float
        
    
    def log(self) -> None:
        print(f"Epoch {self.epoch + 1}: Training Loss: {self.training_loss}\tValidation Loss: {self.validation_loss} || Training F1: {self.training_acc}\tValidation F1: {self.validation_acc}\n----------------------------------------------------")

# %%
history: list[Epoch] = []

for epoch in range(EPOCHS):
    # Define epoch train and test: loss and metrics
    # Make sure to reset the metric function
    epoch_train_loss = 0
    epoch_val_loss = 0
    
    train_metric.reset()
    val_metric.reset()
    
    # TODO: Set the model to training mode
    model.train()
    # Iterate train batches
    for batch in train_dataloader:
        
        # REMEMBER: you need to reset the optimizer in order to avoid incorrect accumulation of gradientrs 
        optim.zero_grad()
        
        # Unpack the batch and move it to the correct device
        inputs, target = batch
        inputs, target = inputs.to(device), target.to(device)

        # get prediction from model
        predictions = model(inputs)
        
        # Calculate loss and metric
        
        loss = criterion(predictions, target)
        train_metric(predictions, target)
        
        # Backward propagataion
        loss.backward()
        optim.step()
        
        # Accumulate train loss
        epoch_train_loss += loss.item()
    
    # Calculate epoch training metric
    epoch_train_f1 = round(train_metric.compute().item(), 3)

    
    # TODO: set the model to test mode
    model.eval()
    # Reset the metric function
    # Make sure PyTorch will run inference without tracking gradients for enhancing performance
    with torch.no_grad():
        # Load batches from `test_loader`
        for batch in test_dataloader:
            
            # Unpack the batch and move it to the correct device
            inputs, target = batch
            inputs, target = inputs.to(device), target.to(device)

            # get prediction from model
            predictions = model(inputs)
            # Calculate loss and metric values
            loss = criterion(predictions, target)
            val_metric(predictions, target)
            
            # Accumulate validation loss
            epoch_val_loss += loss.item()
            
        # Calculate epoch validation metric
        epoch_val_f1 = round(val_metric.compute().item(), 3)
      

    # Calculate epoch training loss
    epoch_train_loss = round(epoch_train_loss / len(train_dataloader), 3)
    # Calculate epoch validation loss
    epoch_val_loss = round(epoch_val_loss / len(test_dataloader), 3)
    
    # Create `Epoch` instance with the results
    epoch_result = Epoch(epoch=epoch, 
                         training_loss=epoch_train_loss, 
                         validation_loss=epoch_val_loss,
                         training_acc=epoch_train_f1,
                         validation_acc=epoch_val_f1,
                        )
    
    # Add to history list
    history.append(epoch_result)
    # Log epoch output
    epoch_result.log()
# Out:
# /Users/anas/PythonProjects/PyTorch-learning/pytorch/lib/python3.12/site-packages/torch/nn/functional.py:2151: UserWarning: The operator 'aten::embedding_renorm_' is not currently supported on the MPS backend and will fall back to run on the CPU. This may have performance implications. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/mps/MPSFallback.mm:13.)
#   torch.embedding_renorm_(weight.detach(), input, max_norm, norm_type)
# Epoch 1: Training Loss: 1.089	Validation Loss: 1.049 || Training F1: 0.381	Validation F1: 0.472
# ----------------------------------------------------
# Epoch 2: Training Loss: 1.053	Validation Loss: 1.059 || Training F1: 0.474	Validation F1: 0.472
# ----------------------------------------------------
# Epoch 3: Training Loss: 1.043	Validation Loss: 1.047 || Training F1: 0.472	Validation F1: 0.472
# ----------------------------------------------------
# Epoch 4: Training Loss: 1.009	Validation Loss: 0.979 || Training F1: 0.493	Validation F1: 0.499
# ----------------------------------------------------
# Epoch 5: Training Loss: 0.904	Validation Loss: 0.897 || Training F1: 0.58	Validation F1: 0.548
# ----------------------------------------------------
# Epoch 6: Training Loss: 0.827	Validation Loss: 0.873 || Training F1: 0.635	Validation F1: 0.575
# ----------------------------------------------------
# Epoch 7: Training Loss: 0.754	Validation Loss: 0.889 || Training F1: 0.668	Validation F1: 0.594
# ----------------------------------------------------
# Epoch 8: Training Loss: 0.705	Validation Loss: 0.835 || Training F1: 0.69	Validation F1: 0.602
# ----------------------------------------------------
# Epoch 9: Training Loss: 0.665	Validation Loss: 0.882 || Training F1: 0.701	Validation F1: 0.6
# ----------------------------------------------------
# Epoch 10: Training Loss: 0.64	Validation Loss: 0.848 || Training F1: 0.707	Validation F1: 0.609
# ----------------------------------------------------
# Epoch 11: Training Loss: 0.616	Validation Loss: 0.905 || Training F1: 0.721	Validation F1: 0.609
# ----------------------------------------------------
# Epoch 12: Training Loss: 0.593	Validation Loss: 0.846 || Training F1: 0.725	Validation F1: 0.61
# ----------------------------------------------------
# Epoch 13: Training Loss: 0.577	Validation Loss: 0.847 || Training F1: 0.729	Validation F1: 0.619
# ----------------------------------------------------
# Epoch 14: Training Loss: 0.555	Validation Loss: 0.841 || Training F1: 0.737	Validation F1: 0.626
# ----------------------------------------------------
# Epoch 15: Training Loss: 0.533	Validation Loss: 0.847 || Training F1: 0.739	Validation F1: 0.622
# ----------------------------------------------------
# Epoch 16: Training Loss: 0.528	Validation Loss: 0.857 || Training F1: 0.742	Validation F1: 0.622
# ----------------------------------------------------
# Epoch 17: Training Loss: 0.521	Validation Loss: 0.868 || Training F1: 0.743	Validation F1: 0.626
# ----------------------------------------------------
# Epoch 18: Training Loss: 0.508	Validation Loss: 0.865 || Training F1: 0.744	Validation F1: 0.627
# ----------------------------------------------------
# Epoch 19: Training Loss: 0.5	Validation Loss: 0.874 || Training F1: 0.751	Validation F1: 0.627
# ----------------------------------------------------
# Epoch 20: Training Loss: 0.494	Validation Loss: 0.872 || Training F1: 0.751	Validation F1: 0.631
# ----------------------------------------------------
# Epoch 21: Training Loss: 0.484	Validation Loss: 0.88 || Training F1: 0.754	Validation F1: 0.629
# ----------------------------------------------------
# Epoch 22: Training Loss: 0.472	Validation Loss: 0.952 || Training F1: 0.766	Validation F1: 0.629
# ----------------------------------------------------
# Epoch 23: Training Loss: 0.453	Validation Loss: 0.874 || Training F1: 0.785	Validation F1: 0.627
# ----------------------------------------------------
# Epoch 24: Training Loss: 0.437	Validation Loss: 1.024 || Training F1: 0.808	Validation F1: 0.663
# ----------------------------------------------------
# Epoch 25: Training Loss: 0.414	Validation Loss: 0.883 || Training F1: 0.82	Validation F1: 0.688
# ----------------------------------------------------
# Epoch 26: Training Loss: 0.393	Validation Loss: 0.895 || Training F1: 0.846	Validation F1: 0.691
# ----------------------------------------------------
# Epoch 27: Training Loss: 0.377	Validation Loss: 0.883 || Training F1: 0.846	Validation F1: 0.686
# ----------------------------------------------------
# Epoch 28: Training Loss: 0.356	Validation Loss: 0.959 || Training F1: 0.862	Validation F1: 0.695
# ----------------------------------------------------
# Epoch 29: Training Loss: 0.337	Validation Loss: 0.893 || Training F1: 0.882	Validation F1: 0.683
# ----------------------------------------------------
# Epoch 30: Training Loss: 0.321	Validation Loss: 0.906 || Training F1: 0.886	Validation F1: 0.686
# ----------------------------------------------------

# %%
train_loss = list(map(lambda x: x.training_loss ,history))
val_loss = list(map(lambda x: x.validation_loss ,history))
train_acc = list(map(lambda x: x.training_acc, history))
val_acc = list(map(lambda x: x.validation_acc, history))


fig, (ax1, ax2) = plt.subplots(figsize=(15, 12), ncols=2)

ax1.plot(range(EPOCHS), train_loss, label="Training")
ax1.plot(range(EPOCHS), val_loss, label="Validation")

ax2.plot(range(EPOCHS), train_acc, label="Training")
ax2.plot(range(EPOCHS), val_acc, label="Validation")

ax1.set_title("Loss", fontdict=dict(size=15), pad=15)
ax2.set_title("F1", fontdict=dict(size=15), pad=15)

ax1.set_xticks(range(EPOCHS))
ax2.set_xticks(range(EPOCHS))

ax1.set_xlabel("Epoch")
ax2.set_xlabel("Epoch")

plt.legend()
plt.show()

# %% [markdown]
# # Summary

# %% [markdown]
# As seen in the training history plot, the models suffers from overfitting, this can be due to the model complexity or the inseprability of the data.

# %% [markdown]
# # Exercises

# %% [markdown]
# - Use pretrained embeddings (eg: AraVec)
# - Try different parameters (eg: number of layers, latent dimension, ..etc)
# - Train a statistical ML model (eg: naive bayes, KNN, ..etc)
